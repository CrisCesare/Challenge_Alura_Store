# %% [markdown]
# # **Resumo da Análise - Recomendação**
#
# ####**Objetivo:** Apoiar o Sr João na decisão de qual loja da rede Alura Store vender, com o intuito de iniciar um novo empreendimento, por meio da identificação da loja com menor eficiência. <br><br>
#
# Como base das análises, foram utilizados os seguintes dados:<br>
# <ul>
#   <li>Faturamento;</li>
#   <li>Vendas por Categoria;</li>
#   <li>Média de Avaliação por Loja;</li>
#   <li>Produtos Mais e Menos Vendidos;</li>
#   <li>Frete Médio por Loja.
# </ul><br>
#
# Para justificar a escolha da loja mencionada na conclusão, apresentarei os principais pontos observados durante a análise de dados.<br><br>
#
#
# ##📈 FATURAMENTO##
# ---
# **Observação principal:** As lojas 3 e 4 apresentaram um faturamento abaixo da média.<p>
# **Resumo por loja:**<p>
#
# <u>Loja 1</u>:<br>
# ` ` ` ` ` ` ` ` ` `Apresenta a maior variabilidade no faturamento por trimestre, o que pode indicar sazonalidade ou flutuações significativas na demanda;<br><p>
#
# <u>Loja 2</u>:<br>
# ` ` ` ` ` ` ` ` ` `É a loja com o faturamento mais estável, mantendo uma consistência ao longo dos trimestres;<br><p>
#
# <u>Loja 3</u>:<br>
# ` ` ` ` ` ` ` ` ` `Registrou o maior pico de faturamento no 4º trimestre de 2021. Entretanto, sofreu uma queda de aproximadamente 30% na receita entre o 4º trimestre de 2022 e o 1º de 2023.<br>
# ` ` ` ` ` ` ` ` ` `<u>**Recomendação</u>:** Acompanhar de perto o desempenho desta loja para identificar os fatores que estão impactando negativamente o faturamento;<br><p>
#
# <u>Loja 4</u>:<br>
# ` ` ` ` ` ` ` ` ` `Enfrentou uma redução de cerca de 35% no faturamento entre o 1º e 2º trimestre de 2022. Desde então, mantém o pior desempenho em faturamento entre as lojas.<br><p>
#
# <img src='https://github.com/CrisCesare/Challenge_Alura_Store/blob/main/Graficos/Faturamento%20Total.png?raw=true' alt='Gráfico Faturamento Total'><p>
#
# <img src='https://github.com/CrisCesare/Challenge_Alura_Store/blob/main/Graficos/Faturamento%20Trimestre.png?raw=true' alt='Gráfico Faturamento por Trimestre' style='width: 300%; height: auto'><p><br>
#
#
# ##🏷️ VENDAS POR CATEGORIA##
# ---
# A análise das vendas por categoria revelou que o **Top 5** das categorias mais vendidas em todas as lojas está concentrado nos seguintes segmentos: **Móveis, Eletrônicos, Brinquedos, Eletrodomésticos e Esporte e Lazer.**<br>
#
# As **lojas 1, 2 e 3** apresentam a mesma ordem de categorias de vendas, enquanto na **loja 4** apresenta uma variação nas duas últimas posições. Essa diferença sugere que a venda de quaisquer uma das lojas não impactará significativamente a distribuição das categorias de vendas, mantendo a tendência observada no restante da rede.<br><p>
#
# <img src='https://github.com/CrisCesare/Challenge_Alura_Store/blob/main/Graficos/Vendas%20por%20Categoria.png?raw=true' alt='Gráfico Vendas por Categoria'><p><br>
#
#
# ##✅ MÉDIA DE AVALIAÇÃO POR LOJA##
# ---
# As lojas apresentam uma média em torno da nota 4. Dada a proximidade dos valores médios, foi realizada uma análise detalhada por ano, além da distribuição das avaliações por pontuação, a fim de obter maior clareza sobre o desempenho das lojas.<br>
# A análise histórica revela variações nos índices de avaliação ao longo dos anos para todas as lojas.<p>
# A loja 1 demanda atenção especial, pois figura consistentemente entre aquelas com as menores médias.<p>
# Entre os anos de 2022 e 2023, a loja 2 apresentou uma queda significativa na avaliação, indicando a necessidade de um exame aprofundado do período para identificar os fatores responsáveis pela variação.<p>
# A loja 3 registrou uma queda entre 2020 e 2021, seguida por uma recuperação nos anos posteriores, mantendo uma média estável em 2022 e 2023. Destaca-se como a loja com maior número de avaliações positivas (notas 4 e 5) ao longo de todo o período analisado.<p>
# A loja 4 registrou um aumento expressivo na avaliação entre 2022 e 2023. Recomenda-se um estudo detalhado sobre as ações implementadas para melhoria, possibilitando a replicação dessas estratégias nas demais lojas. Em contrapartida, a loja 4 concentra o maior volume de avaliações negativas (notas 1 e 2), evidenciando que, apesar da evolução recente, ainda há impacto residual da experiência insatisfatória dos anos anteriores.<br><p>
#
# <img src='https://github.com/CrisCesare/Challenge_Alura_Store/blob/main/Graficos/Avaliacoes.png?raw=true' alt='Gráfico Avaliações'><p><br>
#
#
# ##📦 PRODUTOS MAIS E MENOS VENDIDOS##
# ---
# A análise dos produtos mais e menos vendidos por loja indica que cada unidade apresenta variações em seus itens de maior e menor saída. Dessa forma, esse fator não pode ser utilizado como critério decisivo para definir qual loja vender, uma vez que não há correspondência direta entre os itens mais comercializados.<br><p>
#
# <img src='https://github.com/CrisCesare/Challenge_Alura_Store/blob/main/Graficos/Mais%20e%20menos%20vendidos.png?raw=true' alt='Gráfico Produtos mais e menos vendidos'><p><br>
#
#
# ##🚚 FRETE MÉDIO POR LOJA##
# ---
# O frete médio foi segmentado por ano para proporcionar maior clareza na evolução dos custos ao longo do período analisado. A loja 4 apresentou o menor frete na avaliação geral, porém, no último ano, a menor tarifa foi registrada na loja 3, que ocupa a segunda posição no ranking de menores médias de frete ao longo do período.
#
# A loja 1 manteve um custo de frete elevado nos anos anteriores, registrando uma redução em 2022. No entanto, em 2023, houve um aumento significativo, indicando a necessidade de análise para compreender os fatores que influenciaram essa variação.
#
# A loja 2 apresentou um aumento no custo de frete em 2022, mas conseguiu reduzir essa despesa em 2023, atingindo a menor média de frete da loja em todo o período analisado.<br><p>
#
# <img src='https://github.com/CrisCesare/Challenge_Alura_Store/blob/main/Graficos/frete.png?raw=true' alt='Frete médio'><p><br>
#
# ##**Conclusão:**##
# ---
# A análise de faturamento indica que as lojas 3 e 4 apresentam desempenho abaixo da média, sendo candidatas para a venda. A loja 3 aproxima-se da média de faturamento, enquanto a loja 4 registra valores significativamente inferiores.<br>
#
# A loja 4 teve um destaque na avaliação em 2023, no entanto, a loja 3 acumula o maior número de avaliações positivas (notas 4 e 5), posicionando-se como a segunda melhor avaliação no ano de 2023 e apresentando a melhor média ao longo de todo o período analisado.
#
# A análise de vendas por categoria e dos produtos mais e menos vendidos não revelou diferenciações expressivas que possam influenciar a tomada de decisão.
#
# Embora a loja 4 tenha registrado a menor média de frete no período total, a análise anual mostra que a loja 3 manteve custos inferiores em comparação à loja 4. Além disso, o faturamento da loja 3 em 2023 superou o da loja 4, indicando maior rentabilidade.<p><br>
#
# Com base nesses fatores, **recomenda-se a venda da loja 4**. Para mitigar impactos e promover o crescimento das demais lojas, seguem sugestões de melhoria:<p><br>
# <u>Loja 1</u>:
# - Identificar os fatores que impactam a média de avaliação e aplicar ajustes similares aos implementados na loja 4, que elevaram a média em 2023.
# - Avaliar alternativas para redução do custo elevado de frete, incluindo a cotação de outras transportadoras. Considerar replicar os ajustes de frete adotados pela loja 3.<p>
#
# <u>Loja 2</u>:
# - Investigar os fatores que influenciaram a queda da média de avaliação em 2023. Aplicar estratégias bem-sucedidas da loja 4 para elevar a média antes da venda.<p>
#
# <u>Loja 3</u>:
# - Monitorar de perto o desempenho financeiro para identificar fatores que possam impactar o faturamento.
# - Realizar o remanejamento das vendas da loja 4 para a loja 3 antes do fechamento, reduzindo a perda de clientes.

# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
import matplotlib.ticker as ticker

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja1 = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja1.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %% [markdown]
# #1. Análise do faturamento

# %%
#Somando o faturamento total de cada loja
faturamentos = [
    loja1['Preço'].sum(),
    loja2['Preço'].sum(),
    loja3['Preço'].sum(),
    loja4['Preço'].sum()]

#Váriaveis para apresentação anual
dfs = [loja1, loja2, loja3, loja4]
faturamentoanual = []

#Soma de cada loja anualmente
for i in dfs:
  i['Data da Compra'] = pd.to_datetime(i['Data da Compra'], dayfirst=True)
  i['Ano da Compra'] = i['Data da Compra'].dt.year
  faturamentoanual.append(i.groupby('Ano da Compra')['Preço'].sum())

#Váriaveis para apresentação trimestral
faturamento_trimestral = []

#Soma de cada loja trimestralmente
for i in dfs:
    i['Ano_Trimestre'] = i['Data da Compra'].dt.to_period('Q').astype(str)
    i['Ano_Trimestre'] = i['Ano_Trimestre'].apply(lambda x:x.replace('Q', 'T'))
    faturamento_trimestral.append(i.groupby('Ano_Trimestre')['Preço'].sum())

#Apresentação do resultado
for i in range(len(faturamentos)):
  print(f'O faturamento total da Loja {i+1} é de R$ {faturamentos[i]:,.2f}')
# Out:
# O faturamento total da Loja 1 é de R$ 1,534,509.12
# O faturamento total da Loja 2 é de R$ 1,488,459.06
# O faturamento total da Loja 3 é de R$ 1,464,025.03
# O faturamento total da Loja 4 é de R$ 1,384,497.58

# %%
#Váriaveis para apresentação gráfica
lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']
anos = list(faturamentoanual[0].index)
valores_por_loja = [list(faturamento.values) for faturamento in faturamentoanual]
trimestres_todos = sorted(set().union(*[loja.index for loja in faturamento_trimestral]))
valores_por_loja = [list(faturamento.values) for faturamento in faturamento_trimestral]

#Definição de cores e tamanhos dos gráficos
cores_linhas = ['#3344F5', '#9966FF', '#96D7FF', '#FFC0CB']
fig, ax = plt.subplots(1, 2, figsize=(20, 5))
fig, ay = plt.subplots(figsize=(17, 5))

#Gráfico de barras - Faturamento Total
bars = ax[0].bar(lojas, faturamentos, color='#1A237E')
ax[0].set_title('Faturamento Total')
ax[0].yaxis.set_major_formatter(ticker.StrMethodFormatter('R$ {x:,.2f}'))
ax[0].set_ylim(1350000, 1550000)

media_faturamento = sum(faturamentos) / len(faturamentos)
ax[0].axhline(media_faturamento, color='green', linestyle='--', linewidth=2, label=f'Média: R$ {media_faturamento:,.2f}')
ax[0].legend()

for bar in bars:
    height = bar.get_height()
    ax[0].text(bar.get_x() + bar.get_width() / 2, height + 3500, f'R$ {height:,.2f}', ha='center', va='bottom', color='black', fontsize=9)

#Gráfico de linhas - Anual
for i, loja in enumerate(faturamentoanual):
  anos = loja.index
  valores = loja.values
  ax[1].plot(anos, valores, marker='o', label=f'Loja {i + 1}', color = cores_linhas[i])
  for ano, valor in zip(anos, valores):
    ax[1].text(ano, valor, f'{valor:,.0f}', color = cores_linhas[i], ha='center', va='bottom', fontsize=9)

anos_todos = sorted(set().union(*[loja.index for loja in faturamentoanual]))
ax[1].margins(0.055)
ax[1].set_xticks(anos_todos)
ax[1].set_xticklabels(anos_todos)
ax[1].set_title('Faturamento por Ano')
ax[1].legend(title='Lojas')
ax[1].yaxis.set_major_formatter(ticker.StrMethodFormatter('R$ {x:,.2f}'))

#Gráfico de linhas - Trimestral
for i, loja in enumerate(faturamento_trimestral):
    trimestres = loja.index.astype(str)
    valores = loja.values
    ay.plot(trimestres, valores, marker='o', label=f'Loja {i + 1}', color=cores_linhas[i])
    for trimestre, valor in zip(trimestres, valores):
        ay.text(trimestre, valor, f'{valor:,.0f}', color=cores_linhas[i], ha='center', va='bottom', fontsize=9)

ay.margins(0.055)
ay.set_xticks(range(len(trimestres_todos)))
ay.set_xticklabels([str(trimestre).replace('T', ' T') for trimestre in trimestres_todos], rotation=45)
ay.set_title('Faturamento por Trimestre')
ay.legend(title='Lojas')
ay.yaxis.set_major_formatter(ticker.StrMethodFormatter('R$ {x:,.2f}'))

#Ajustes finais dos gráficos
plt.subplots_adjust(wspace=6)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. Vendas por Categoria

# %%
#Quantidade de vendas por categoria
venda_categorias = [
    loja1['Categoria do Produto'].value_counts().head(5),
    loja2['Categoria do Produto'].value_counts().head(5),
    loja3['Categoria do Produto'].value_counts().head(5),
    loja4['Categoria do Produto'].value_counts().head(5)]

#Apresentação do Top 5 categorias
for i in range(len(venda_categorias)):
  print(f'As categorias mais populares (Top 5) da Loja {i+1} são: \n{venda_categorias[i]}')
  if i > 2:
    continue
  print()
# Out:
# As categorias mais populares (Top 5) da Loja 1 são:
# Categoria do Produto
# moveis              465
# eletronicos         448
# brinquedos          324
# eletrodomesticos    312
# esporte e lazer     284
# Name: count, dtype: int64
#
# As categorias mais populares (Top 5) da Loja 2 são:
# Categoria do Produto
# moveis              442
# eletronicos         422
# brinquedos          313
# eletrodomesticos    305
# esporte e lazer     275
# Name: count, dtype: int64
#
# As categorias mais populares (Top 5) da Loja 3 são:
# Categoria do Produto
# moveis              499
# eletronicos         451
# brinquedos          315
# eletrodomesticos    278
# esporte e lazer     277
# Name: count, dtype: int64
#
# As categorias mais populares (Top 5) da Loja 4 são:
# Categoria do Produto
# moveis              480
# eletronicos         451
# brinquedos          338
# esporte e lazer     277
# eletrodomesticos    254
# Name: count, dtype: int64

# %%
# Cores dos gráficos
cores = ['#3344F5', '#9966FF', '#96D7FF', '#FFC0CB', '#FF6961', '#77DD77', '#FFD700', '#00BFFF', '#FF4500']
categorias_unicas = set()

# Definindo 4 gráficos um ao lado do outro
fig, axes = plt.subplots(1, 4, figsize=(20, 5))
fig.suptitle('Top 5 - Vendas por Categoria', fontsize=28)

#Gerando dados dos gráficos
for i in range(4):
    categorias_unicas.update(venda_categorias[i].index)
    cores_map = {categoria: cores[j % len(cores)] for j, categoria in enumerate(sorted(categorias_unicas))}
    total = venda_categorias[i].sum()
    axes[i].pie(venda_categorias[i], labels=venda_categorias[i].index, colors=[cores_map[categoria] for categoria in venda_categorias[i].index],
                autopct=lambda pct: f'{pct:.1f}%\n({int(round(pct * total / 100))})', startangle=90, counterclock=False)
    axes[i].set_title(lojas[i])

# Ajustes finais dos gráficos
plt.subplots_adjust(wspace=5)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
#Média da avaliação por loja
avaliacoes = [
    round(loja1['Avaliação da compra'].mean(),2),
    round(loja2['Avaliação da compra'].mean(),2),
    round(loja3['Avaliação da compra'].mean(),2),
    round(loja4['Avaliação da compra'].mean(),2)]

#Váriavel para média anualmente
avaliacaoanual = []

#Média de cada loja anualmente
for i in dfs:
  agrupamento = i.groupby('Ano da Compra')['Avaliação da compra'].mean()
  avaliacaoanual.append(agrupamento.round(2))

#Quantidade de avaliações por nota
avaliacao_notas = [
    loja1['Avaliação da compra'].value_counts().sort_index().head(),
    loja2['Avaliação da compra'].value_counts().sort_index().head(),
    loja3['Avaliação da compra'].value_counts().sort_index().head(),
    loja4['Avaliação da compra'].value_counts().sort_index().head()
]

#Apresentação do resultado
for i in range(len(avaliacoes)):
  print(f'A média de avaliação da Loja {i+1} é de {avaliacoes[i]}')
# Out:
# A média de avaliação da Loja 1 é de 3.98
# A média de avaliação da Loja 2 é de 4.04
# A média de avaliação da Loja 3 é de 4.05
# A média de avaliação da Loja 4 é de 4.0

# %%
#Definição da distribuição dos gráficos
fig, ax = plt.subplots(1, 3, figsize=(30, 7))

#Gráfico 1
bars = ax[0].barh(lojas, avaliacoes, color='#1A237E')
ax[0].set_title('Média de Avaliação dos Clientes', fontsize=16)
ax[0].set_xlim(3.50, 4.10)
ax[0].invert_yaxis()

for bar in bars:
    width = bar.get_width()
    ax[0].text(width, bar.get_y() + bar.get_height() / 2, f'{width: .2f}', ha='left', va='center', color='black', fontsize=10)

#Gráfico 2
for i, loja in enumerate(avaliacaoanual):
  anos = loja.index
  valores = loja.values
  ax[1].plot(anos, valores, marker='o', label=f'Loja {i + 1}', color = cores_linhas[i])
  for ano, valor in zip(anos, valores):
    ax[1].text(ano, valor, f'{valor:,.2f}', color = cores_linhas[i], ha='center', va='bottom', fontsize=9)

anos_todos = sorted(set().union(*[loja.index for loja in avaliacaoanual]))
ax[1].margins(0.055)
ax[1].set_xticks(anos_todos)
ax[1].set_xticklabels(anos_todos)
ax[1].set_title('Avaliação por Ano', fontsize=16)
ax[1].legend(title='Lojas')

#Gráfico 3
notas = sorted(set().union(*[avaliacao_notas[i].index for i in range(4)]))
notas_com_texto = [f'Nota {nota}' for nota in notas]  # Adicionando 'Nota' antes de cada valor de nota
largura = 0.2

for i in range(4):
    valores = [avaliacao_notas[i].get(nota, 0) for nota in notas]
    posicoes = [j + largura * i for j in range(len(notas))]
    ax[2].bar(posicoes, valores, largura, label=lojas[i], color=cores_linhas[i])
    for pos, valor in zip(posicoes, valores):
        ax[2].text(pos, valor + 0.5, f'{valor}', ha='center', va='bottom', fontsize=10)

posicoes_centrais = [j + largura * 1.5 for j in range(len(notas))]  # Definindo posições centrais
ax[2].set_xticks(posicoes_centrais)
ax[2].set_xticklabels(notas_com_texto)  # Aplicando as etiquetas com texto adicional
ax[2].legend(title='Lojas')
ax[2].set_title('Quantidade Avaliações por Nota', fontsize=16)

#Ajustes finais dos gráficos
plt.subplots_adjust(wspace=5)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
#Quantidade de produtos vendidos
venda_produtos = [
    loja1['Produto'].value_counts(),
    loja2['Produto'].value_counts(),
    loja3['Produto'].value_counts(),
    loja4['Produto'].value_counts()]

#Variavéis para lista de produtos mais e menos vendidos
produtos_mais_vendidos = []
produtos_menos_vendidos = []

#Extração dos produtos mais e menos vendidos por loja
for vendas in venda_produtos:
    max_vendas = vendas.max()
    min_vendas = vendas.min()
    produtos_max = vendas[vendas == max_vendas]
    produtos_min = vendas[vendas == min_vendas]
    produtos_mais_vendidos.append(produtos_max)
    produtos_menos_vendidos.append(produtos_min)

#Apresentação do resultado
for i in range(len(produtos_mais_vendidos)):
    print(f"Loja {i + 1} - Produtos mais vendidos:")
    for produto, quantidade in produtos_mais_vendidos[i].items():
        print(f" - {produto}: {quantidade} vendas")
    print()

    print(f"Loja {i + 1} - Produtos menos vendidos:")
    for produto, quantidade in produtos_menos_vendidos[i].items():
        print(f" - {produto}: {quantidade} vendas")
    print()
    if i > 2:
        continue
    print("-" * 40)
    print()
# Out:
# Loja 1 - Produtos mais vendidos:
#  - Micro-ondas: 60 vendas
#  - TV Led UHD 4K: 60 vendas
#  - Guarda roupas: 60 vendas
#
# Loja 1 - Produtos menos vendidos:
#  - Headset: 33 vendas
#  - Celular ABXY: 33 vendas
#
# ----------------------------------------
#
# Loja 2 - Produtos mais vendidos:
#  - Iniciando em programação: 65 vendas
#
# Loja 2 - Produtos menos vendidos:
#  - Jogo de tabuleiro: 32 vendas
#
# ----------------------------------------
#
# Loja 3 - Produtos mais vendidos:
#  - Kit banquetas: 57 vendas
#
# Loja 3 - Produtos menos vendidos:
#  - Blocos de montar: 35 vendas
#
# ----------------------------------------
#
# Loja 4 - Produtos mais vendidos:
#  - Cama box: 62 vendas
#
# Loja 4 - Produtos menos vendidos:
#  - Guitarra: 33 vendas

# %%
#Variável para agrupar itens
produtos_agrupados = []

#Agrupando os dados
for i in range(len(venda_produtos)):
    loja_atual = f"Loja {i + 1}"
    produtos_da_loja = produtos_mais_vendidos[i].index.tolist() + produtos_menos_vendidos[i].index.tolist()

    for produto in produtos_da_loja:
        dados_produto = {
            "Produto": produto,
            "Loja de Origem": loja_atual,
            "Vendas": {}
        }
        for j in range(len(venda_produtos)):
            loja_analisada = f"Loja {j + 1}"
            quantidade_vendida = venda_produtos[j].get(produto, 0)  # Obter quantidade ou 0 caso não exista
            dados_produto["Vendas"][loja_analisada] = quantidade_vendida

        produtos_agrupados.append(dados_produto)

#Convertendo os dados em DataFrame
dados_para_grafico = []
for produto_info in produtos_agrupados:
    for loja, quantidade in produto_info["Vendas"].items():
        dados_para_grafico.append({
            "Produto": produto_info["Produto"],
            "Loja": loja,
            "Quantidade Vendida": quantidade
        })

df_grafico = pd.DataFrame(dados_para_grafico)

#Configuração do gráfico
plt.figure(figsize=(28, 8))
produtos_unicos = df_grafico["Produto"].unique()
lojas_unicas = df_grafico["Loja"].unique()
largura = 0.8 / len(lojas_unicas)

for i, loja in enumerate(lojas_unicas):
    df_loja = df_grafico[df_grafico["Loja"] == loja]
    x = range(len(produtos_unicos))
    y = [df_loja[df_loja["Produto"] == produto]["Quantidade Vendida"].sum() for produto in produtos_unicos]

    barras = []
    for pos, produto in enumerate(produtos_unicos):
      if produto in produtos_mais_vendidos[i]:
        hatch = '////'
        facecolor = cores_linhas[i]
        edgecolor = 'white'
      elif produto in produtos_menos_vendidos[i]:
        hatch = '...'
        facecolor = cores_linhas[i]
        edgecolor = 'white'
      else:
            hatch = None
            facecolor = cores_linhas[i]
            edgecolor = 'none'

      barra = plt.bar(pos + i * largura, y[pos], width=largura, label=loja if pos == 0 else "", facecolor=facecolor, edgecolor=edgecolor, hatch=hatch)
      barras.append(barra)

    for barra in barras:
        for b in barra:
            plt.text(b.get_x() + b.get_width() / 2, b.get_height() + 0.5, int(b.get_height()), ha="center", va="bottom", fontsize=12)

handles = [Patch(facecolor=cores_linhas[i], label=loja) for i, loja in enumerate(lojas_unicas)]
plt.legend(handles=handles, title="Lojas", loc="upper right")

#Ajustes finais do gráfico
plt.xticks([pos + largura * (len(lojas_unicas) - 1) / 2 for pos in range(len(produtos_unicos))], produtos_unicos, fontsize=12)
plt.title("Desempenho de Produtos por Loja", fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
#Média do frete por loja
valor_frete = [
    round(loja1['Frete'].mean(),2),
    round(loja2['Frete'].mean(),2),
    round(loja3['Frete'].mean(),2),
    round(loja4['Frete'].mean(),2)]

#Váriavel para média anualmente
freteanual = []

#Média de cada loja anualmente
for i in dfs:
  agrupamento = i.groupby('Ano da Compra')['Frete'].mean()
  freteanual.append(agrupamento.round(2))

media_frete = round((loja1['Frete'].sum() + loja2['Frete'].sum() + loja3['Frete'].sum() + loja4['Frete'].sum()) / (len(loja1['Frete']) + len(loja2['Frete']) + len(loja3['Frete']) + len(loja4['Frete'])),2)

#Apresentação do resultado
for i in range(len(valor_frete)):
  print(f'A média de frete da Loja {i+1} é de R$ {valor_frete[i]}')
# Out:
# A média de frete da Loja 1 é de R$ 34.69
# A média de frete da Loja 2 é de R$ 33.62
# A média de frete da Loja 3 é de R$ 33.07
# A média de frete da Loja 4 é de R$ 31.28

# %%
#Definição da distribuição dos gráficos
fig, ax = plt.subplots(1, 2, figsize=(20, 6))

#Gráfico 1
for i, (loja, cor) in enumerate(zip(lojas, cores_linhas)):
  ax[0].scatter(loja, valor_frete[i], color = cores_linhas[i], marker='d', label=f'{loja}')
  ax[0].text(loja, valor_frete[i] - 0.2, f'R$ {valor_frete[i]:.2f}', fontsize=12, ha='center')

def formatar_real(valor, pos):
    return f'R$ {valor:.2f}'

formatter = ticker.FuncFormatter(formatar_real)

ax[0].axhline(y=media_frete, color='green', linestyle='--', label=f'Média: R$ {media_frete}')
ax[0].set_title('Frete Médio por Loja', fontsize=14)
ax[0].legend(title='Lojas', loc='upper right', fontsize=10)
ax[0].set_ylim(31.00, 35.00,)
ax[0].yaxis.set_major_formatter(formatter)
ax[0].yaxis.set_major_locator(ticker.MaxNLocator(integer=True))

#Gráfico 2
for i, loja in enumerate(freteanual):
  anos = loja.index
  valores = loja.values
  ax[1].plot(anos, valores, marker='d', label=f'Loja {i + 1}', color = cores_linhas[i])
  for ano, valor in zip(anos, valores):
    ax[1].text(ano, valor, f'{valor:.2f}', color = cores_linhas[i], ha='center', va='bottom', fontsize=9)

anos_todos = sorted(set().union(*[loja.index for loja in avaliacaoanual]))
ax[1].margins(0.055)
ax[1].set_xticks(anos_todos)
ax[1].set_xticklabels(anos_todos)
ax[1].set_title('Frete Médio por Ano', fontsize=16)
ax[1].legend(title='Lojas')

#Ajustes finais dos gráficos
plt.subplots_adjust(wspace=5)
plt.tight_layout()
plt.show()
